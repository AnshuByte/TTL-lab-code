# %%
#Experiment-7: Create a list of numbers and perform various operations such as adding elements, removing elements, and accessing elements by index.

numbers = [2,3,1,9,6,7]
print(numbers)
numbers.append(7)
numbers.insert(2, 4)
print("After adding elements:", numbers)
addition = sum(numbers)
print("The sum of the numbers is:", addition)
addition = sum(numbers)
numbers.remove(3)
del numbers[0]
print("After removing elements:", numbers)
print("The sum of the numbers is:", sum(numbers))
print("Elemet at index 2:", numbers[2])
print("Last element:", numbers[-1])
# Out:
# [2, 3, 1, 9, 6, 7]
# After adding elements: [2, 3, 4, 1, 9, 6, 7, 7]
# The sum of the numbers is: 39
# After removing elements: [4, 1, 9, 6, 7, 7]
# The sum of the numbers is: 34
# Elemet at index 2: 9
# Last element: 7

# %%
#Experiment-8: Create a tuple to represent an immutable collection and try accessing elements and performing basic operations.

my_tuple = (5,4,3,2,1)

print(my_tuple)

print("Element at index 1:", my_tuple[1])
print("Last elemnt:", my_tuple[-1])

a, b, c, d, e = my_tuple     #Unpacking
a = 8
print("Tuple unpacking:", a, b, c, d, e)
print("Length of tuple:", len(my_tuple))

another_tuple = (6, 7, 8)
combined_tuple = my_tuple + another_tuple
print("Concatenated tuple:", combined_tuple)
# Out:
# (5, 4, 3, 2, 1)
# Element at index 1: 4
# Last elemnt: 1
# Tuple unpacking: 8 4 3 2 1
# Length of tuple: 5
# Concatenated tuple: (5, 4, 3, 2, 1, 6, 7, 8)

# %%
#Experiment-9: Create a set to store unique elements and perform set operations such as union, intersection, and difference.

set1 = {1, 2, 3, 4, 5, 6}
set2 = {7,6,5,4,3,2,1,0}

union = set1.union(set2)
print("Union:", union)

intersect = set1.intersection(set2)
print("Intersection:", intersect)

difference = set1.difference(set2)
print("Difference (set1 - set2):", difference)

difference = set2.difference(set1)
# sdiff = sorted(difference)
print("Difference (set2 - set1):", difference)
# Out:
# Union: {0, 1, 2, 3, 4, 5, 6, 7}
# Intersection: {1, 2, 3, 4, 5, 6}
# Difference (set1 - set2): set()
# Difference (set2 - set1): {0, 7}

# %%
#Experiment-10: Create a dictionary to represent key-value pairs and perform operations like adding, updating, and accessing values.

my_dict = {
    "grape" : 2,
    "pineapple" : 3,
    "lemon" : 4
}

print("Number of grapes:", my_dict["grape"])
print("Number of pineapples:", my_dict.get("pineapple"))

my_dict["kiwi"] = 6
print("Updated dictionary after adding kiwi:", my_dict)

my_dict["grape"] = 5
print("Updated dictionary:", my_dict)
print("Number of grapes:", my_dict["grape"])
print("Number of pineapples:", my_dict.get("pineapple"))

del my_dict["lemon"]
print("Updated after removing lemon:", my_dict)
# Out:
# Number of grapes: 2
# Number of pineapples: 3
# Updated dictionary after adding kiwi: {'grape': 2, 'pineapple': 3, 'lemon': 4, 'kiwi': 6}
# Updated dictionary: {'grape': 5, 'pineapple': 3, 'lemon': 4, 'kiwi': 6}
# Number of grapes: 5
# Number of pineapples: 3
# Updated after removing lemon: {'grape': 5, 'pineapple': 3, 'kiwi': 6}

# %%
# Case Study: Library Management System

# Case Study: Library Management System

# Define the Book class
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.available = True

    def borrow(self):
        if self.available:
            self.available = False
            print(f"The book '{self.title}' by {self.author} has been borrowed.")
        else:
            print(f"Sorry, the book '{self.title}' is currently not available.")

    def return_book(self):
        if not self.available:
            self.available = True
            print(f"The book '{self.title}' by {self.author} has been returned.")
        else:
            print(f"The book '{self.title}' by {self.author}' is already available in the library.")

# Define the Library class
class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        print(f"The book '{book.title}' by {book.author} has been added to the library.")

    def display_available_books(self):
        available_books = [book for book in self.books if book.available]
        if available_books:
            print("Available books in the library:")
            for book in available_books:
                print(f"'{book.title}' by {book.author}")
        else:
            print("No books available in the library.")

# Create Book objects
book1 = Book("The Catcher in the Rye", "J.D. Salinger")
book2 = Book("Pride and Prejudice", "Jane Austen")
book3 = Book("The Alchemist", "Paulo Coelho")

# Create Library object
library = Library()

# Add books to the library
library.add_book(book1)
library.add_book(book2)
library.add_book(book3)
print()
# Display available books
library.display_available_books()
print()
# Borrow a book
book1.borrow()
print()
# Display available books after borrowing
library.display_available_books()
print()
# Return a book
book1.return_book()
print()
# Display available books after returning
library.display_available_books()
# Out:
# The book 'The Catcher in the Rye' by J.D. Salinger has been added to the library.
# The book 'Pride and Prejudice' by Jane Austen has been added to the library.
# The book 'The Alchemist' by Paulo Coelho has been added to the library.
#
# Available books in the library:
# 'The Catcher in the Rye' by J.D. Salinger
# 'Pride and Prejudice' by Jane Austen
# 'The Alchemist' by Paulo Coelho
#
# The book 'The Catcher in the Rye' by J.D. Salinger has been borrowed.
#
# Available books in the library:
# 'Pride and Prejudice' by Jane Austen
# 'The Alchemist' by Paulo Coelho
#
# The book 'The Catcher in the Rye' by J.D. Salinger has been returned.
#
# Available books in the library:
# 'The Catcher in the Rye' by J.D. Salinger
# 'Pride and Prejudice' by Jane Austen
# 'The Alchemist' by Paulo Coelho

# %%
# Financial Portfolio Management System

# Financial Portfolio Management System

class Asset:
    def __init__(self, name, quantity, price):
        self.name = name
        self.quantity = quantity
        self.price = price

    def value(self):
        return self.quantity * self.price


class Portfolio:
    def __init__(self):
        self.assets = []

    def add_asset(self, asset):
        self.assets.append(asset)
        print(f"Asset '{asset.name}' added to the portfolio.")

    def remove_asset(self, asset_name):
        for asset in self.assets:
            if asset.name == asset_name:
                self.assets.remove(asset)
                print(f"Asset '{asset_name}' removed from the portfolio.")
                return
        print(f"No asset named '{asset_name}' found in the portfolio.")

    def total_value(self):
        total_value = sum(asset.value() for asset in self.assets)
        return total_value

    def display_assets(self):
        if not self.assets:
            print("Portfolio is empty.")
            return
        print("Assets in the portfolio:")
        for asset in self.assets:
            print(f"Name: {asset.name}, Quantity: {asset.quantity}, Price: {asset.price}, Total Value: {asset.value()}")


# Create instances of Asset representing different assets
stock1 = Asset("Microsoft Corporation", 10, 150)
bond1 = Asset("Municipal Bond", 5, 1000)
cash = Asset("Savings Account", 50000, 1)

# Create a Portfolio instance
portfolio = Portfolio()

# Add assets to the portfolio
portfolio.add_asset(stock1)
portfolio.add_asset(bond1)
portfolio.add_asset(cash)
print()
# Display assets in the portfolio
portfolio.display_assets()
print()
# Remove an asset from the portfolio
portfolio.remove_asset("Municipal Bond")
print()
# Display assets in the portfolio after removal
portfolio.display_assets()
print()
# Calculate the total value of the portfolio
total_value = portfolio.total_value()
print(f"Total value of the portfolio: ${total_value}")
# Out:
# Asset 'Microsoft Corporation' added to the portfolio.
# Asset 'Municipal Bond' added to the portfolio.
# Asset 'Savings Account' added to the portfolio.
#
# Assets in the portfolio:
# Name: Microsoft Corporation, Quantity: 10, Price: 150, Total Value: 1500
# Name: Municipal Bond, Quantity: 5, Price: 1000, Total Value: 5000
# Name: Savings Account, Quantity: 50000, Price: 1, Total Value: 50000
#
# Asset 'Municipal Bond' removed from the portfolio.
#
# Assets in the portfolio:
# Name: Microsoft Corporation, Quantity: 10, Price: 150, Total Value: 1500
# Name: Savings Account, Quantity: 50000, Price: 1, Total Value: 50000
#
# Total value of the portfolio: $51500
